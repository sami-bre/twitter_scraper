# %% [markdown]
# # setup

# %%
# %pip install tavily-python dotenv openai
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
from tavily import TavilyClient
import requests
import os
import json
from pprint import pprint


load_dotenv()
# Out:
# True

# %% [markdown]
# # The search keyword

# %%
search_keywrod = "Jeff Delaney blog article"

# %% [markdown]
# # Getting search results from tavily

# %%
# To install: pip install tavily-python

client = TavilyClient("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")
response = client.search(
    query=search_keywrod,
    include_raw_content=True,
    max_results=6
)


raw_contents = [
    {
    "url": item["url"],
    "raw_content": item["raw_content"]
    } 
    for item in response["results"] if item["raw_content"] is not None
]

print(len(raw_contents))
# Out:
# 5

# %%
prompt_template = """
I will give you a scrapped web page content. identify if the content is a blog post or not and write a short summary of the content. Add no markup. Answer in the following json format:

--------------- answer format ------------------

{{
"is_blog_post": true,
"summary": "This is a summary of the blog post"
}}

------------- example content -----------------

'Published Time: 2017-05-08T08:29:15.861Z\n'
'Feedpresso — Second month at StartupYard | by '
'Tadas Šubonis | Medium\n'
'Open in app\n'
'Sign up\n'
'Sign in\n'
'\n'
'Write\n'
'\n'
'Sign up\n'
'Sign in\n'
'\n'
'Feedpresso — Second month at StartupYard\n'
'\n'
'Tadas Šubonis\n'
'·Follow\n'
'3 min read\n'
'·\n'
'May 8, 2017\n'
'\n'
'--\n'
'\n'
'Listen\n'
'Share\n'
'This is the third post about my and Feedpresso '
'experience during the participation of '
'StarpupYard accelerator.\n'
'The second month of StartupYard was mostly '
'workshops in various areas relevant to the life '
'of a startup. Namely:\n'
'\n'
'How to do PR?\n'
'Landing Pages\n'
'User Personas\n'
'Selling to businesses\n'
'Paid Advertising\n'
'Storytelling\n'
'How to do marketing?\n'
'Azure Cloud\n'
'Business Model & Financial Projections\n'
'\n'
'All of these workshops were extremely relevant '
'to us. However, I‘ll describe just a few that '
'stood out the most.\n'
'Business Workshop\n'
'There were many great tips about the way we '
'should talk with businesses. We covered things '
'like how to push businesses to close the deal, '
'how to price your product accordingly '
'(apparently, if you are too cheap, nobody will '
'buy anything from you 😉).\n'
'I feel that it is important to mention the books '
'that Cedric recommends to read:\n'
'\n'
'Influence: The Psychology of Persuasion\n'
'Pitch Anything: An Innovative Method for '
'Presenting, Persuading, and Winning the Deal\n'
'Never Split the Difference: Negotiating As If '
'Your Life Depended On It\n'
'The New Solution Selling: The Revolutionary '
'Sales Process That is Changing the Way People '
'Sell\n'
'Crossing the Chasm: Marketing and Selling '
'High-Tech Products to Mainstream Customers\n'
'\n'
'Unfortunately, I’ve been stuck with Crossing the '
'Chasm for now as I haven’t been reading enough '
':-(.\n'
'Storytelling\n'
'A great workshop that was given by Lloyd. The '
'biggest takeaway here was that everybody cares '
'about your story. Your users, your clients, and '
'even your investors.\n'
'If you cannot tell a story about your startup '
'and yourself, then you are basically nothing. A '
'bit of exaggeration but it is a serious business '
'😊\n'
'However, when you make a story, you shouldn’t '
'forget to make it relevant to the consumer of '
'it.\n'
'We have explored how stories are made '
'(apparently, there are just 6 main arcs) and '
'that each of them should have a: character, '
'setting, conflict, plot, and theme.\n'
'Azure\n'
'This workshop was probably relevant just to me '
'personally. Actually, in the beginning, I even '
'thought that it‘s going to be a waste of time '
'since we’ve been using Azure Cloud for more than '
'a year now so there is little chance that I am '
'going to learn anything useful as it felt that '
'it was tailored more for beginners.\n'
'I was completely wrong. We went to the offices '
'of Microsoft for the workshop which lasted an '
'entire day. Before we started it, guys spent '
'some time figuring out our level and ditched '
'their initial agenda to make it extremely '
'relevant personally to us.\n'
'I got a chance to clarify many advanced details '
'about the way the Azure works. DocumentDB, Azure '
'Function, Blob Storage, and Queues. There were '
'many details that still weren’t clear to me and '
'the guys from Microsoft helped me out a lot.\n'
'Paid Advertising\n'
'We had an opportunity to learn from Marketa '
'Kabátová. There is a saying about AdWords that '
'no person can learn everything there is to learn '
'about AdWords. Apparently, Marketa might be the '
'one that got there.\n'
'There was a lot of to take in from that session '
'and I felt that I missed out a lot by not being '
'experienced (I have run just a few campaigns) '
'enough to make the best use of her knowledge.\n'
'However, one thing definitely struck into my '
'mind and probably many do not know that — '
'whenever bidding for phrases, use the quotes as '
'otherwise the bid is made on two separate '
'keywords — not a phrase. It is really not '
'obvious and can save a fortune for the CPC.\n'
'Conclusion\n'
'In the end, I was really surprised with the '
'quality of the workshops and I was really '
'impressed how relevant all of them are to the '
'startups.\n'
'\n'
'Sign up to discover human stories that deepen '
'your understanding of the world.\n'
'Free\n'
'Distraction-free reading. No ads.\n'
'Organize your knowledge with lists and '
'highlights.\n'
'Tell your story. Find your audience.\n'
'Sign up for free\n'
'Membership\n'
'Read member-only stories\n'
'Support writers you read most\n'
'Earn money for your writing\n'
'Listen to audio narrations\n'
'Read offline with the Medium app\n'
'Try for $5/month\n'
'Cloud Computing\n'
'Azure\n'
'Marketing\n'
'Workshop\n'
'\n'
'--\n'
'\n'
'--\n'
'\n'
'\n'
'\n'
'Follow\n'
'Written by Tadas Šubonis '
'193 Followers\n'
'·540 Following\n'
'Geek. Data Scientist. Software Engineer. '
'Entrepreneur.\n'
'Follow\n'
'No responses yet\n'
'\n'
'\n'
'Write a response\n'
'What are your thoughts?\n'
'Cancel\n'
'Respond\n'
'Also publish to my profile\n'
'Help\n'
'Status\n'
'About\n'
'Careers\n'
'Press\n'
'Blog\n'
'Privacy\n'
'Terms\n'
'Text to speech\n'
'Teams'

--------- answer for the example -------------
{{
"is_blog_post": true,
"summary": "The blog post by Tadas Šubonis details his second month at the StartupYard accelerator with his startup, Feedpresso. During this period, he attended various workshops covering key aspects of running a startup, including PR, marketing, user personas, business sales, storytelling, and cloud computing with Azure. Highlights include insights on business negotiation, effective storytelling, and advanced Azure functionalities. He also shares valuable book recommendations on persuasion and sales. Overall, the post reflects his appreciation for the quality and relevance of the workshops to startup success."
}}

--------------- content -----------------------------

{scraped_content}
"""

# %% [markdown]
# # Check if a result is blog post

# %%
gemini_api_key = os.getenv("GEMINI_API_KEY")

def is_content_blog(content):
    url = f"https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-flash:generateContent?key={gemini_api_key}"

    headers = {
        "Content-Type": "application/json"
    }

    

    data = {
        "contents": [
            {
                "parts": [
                    {"text": prompt_template.format(scraped_content=content)}
                ]
            }
        ]
    }

    response = requests.post(url, headers=headers, json=data)
    result = response.json()
    return result

# %%
def extract_json_data(result: dict) -> dict:
    # Get the text from the first candidate
    json_text = result["candidates"][0]["content"]["parts"][0]["text"]

    # Remove leading markdown formatting (```json) and trailing formatting (```)
    start = json_text.find("```json")
    if start != -1:
        start += len("```json")
    else:
        start = 0
    end = json_text.find("```", start)
    json_str = json_text[start:end].strip()

    # Load and return the JSON data from the extracted string
    return json.loads(json_str)

# %% [markdown]
# # Check the first result

# %%
res = is_content_blog(raw_contents[0]["raw_content"])
print(res)
# Out:
# {'candidates': [{'content': {'parts': [{'text': '```json\n{\n  "is_blog_post": false,\n  "summary": "This is a website page for a screenwriter, Jeff, showcasing his awards, scripts, and contact information.  It includes a brief anecdote about winning an award and a mention of his work on a sci-fi comedy. The page also lists categories of available scripts."\n}\n```\n'}], 'role': 'model'}, 'finishReason': 'STOP', 'avgLogprobs': -0.2214439488664458}], 'usageMetadata': {'promptTokenCount': 2019, 'candidatesTokenCount': 79, 'totalTokenCount': 2098, 'promptTokensDetails': [{'modality': 'TEXT', 'tokenCount': 2019}], 'candidatesTokensDetails': [{'modality': 'TEXT', 'tokenCount': 79}]}, 'modelVersion': 'gemini-1.5-flash'}

# %%
final_result = extract_json_data(res)
pprint(final_result)
# Out:
# {'is_blog_post': False,
#  'summary': 'This is a website page for a screenwriter, Jeff, showcasing his '
#             'awards, scripts, and contact information.  It includes a brief '
#             'anecdote about winning an award and a mention of his work on a '
#             'sci-fi comedy. The page also lists categories of available '
#             'scripts.'}

# %% [markdown]
# # Check all results

# %%
for idx, item in enumerate(raw_contents):
    
    print(f"Processing raw_content at index {idx}")
    try:
        res = is_content_blog(item["raw_content"])
        final_result = extract_json_data(res)
        final_result["url"] = item["url"]
        pprint(final_result)
        print()
    except Exception as e:
        print(f"Error processing content at index {idx}: {e}")
# Out:
# Processing raw_content at index 0
# {'is_blog_post': False,
#  'summary': 'This is a website footer or about page for Script Revolution Ltd, '
#             "a company that offers scripts.  It mentions Jeff's award win and "
#             'a brief anecdote about his career, followed by a list of script '
#             'categories and contact information.  It is not a blog post, but '
#             'rather company information.',
#  'url': 'https://www.scriptrevolution.com/profiles/jeff-delaney'}
#
# Processing raw_content at index 1
# {'is_blog_post': False,
#  'summary': 'This is not a single blog post but a collection of blog post '
#             'titles and authors, organized potentially by publication or '
#             'author.  The page shows snippets of several articles on topics '
#             'such as becoming a Google Developer Expert, programming '
#             'languages, hybrid app development, full-stack Vue.js, and the '
# ...
